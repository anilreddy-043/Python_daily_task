# %%
import pandas as pd
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 1 – Complete Data Cleaning
#Your manager gives you a messy dataset.
#Perform all of the following:

#• Load the dataset.
import pandas as pd
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
print(df)

#• Display dataset information.
df.info()
print(df)

#• Find missing values.
df.isnull()
print(df)

#• Remove duplicate rows.
df.dropna(inplace = True)
print(df)

#• Fill missing values:
#o Age → median
Age_median = df["Age"].median()
Age_median
print(Age_median)
#o Balance → mean
Balance_median = df["Balance"].mean()
print(Balance_median)

#print(int(Balance_median))
#• Rename:
#o Target → CustomerStatus
df.rename(columns = {
    "Target":"CustomerStatus",
    
},inplace = True)
print(df)
#o AnnualIncome → Income
df.rename(columns = {
    "AnnualIncome":"Income",
    
},inplace = True)
print(df)
#• Display the first 15 rows.
#df.head(15)
##Methods expected:
#read_csv()
#info()
#isnull()
#drop_duplicates()
#median()
#mean()
#fillna()
#rename()
#head()
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 2 – Banking Report
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#The bank wants a numeric report.
#---->Tasks
#• Select only numeric columns.
df.select_dtypes(include = ["int"]).columns
print(df)
#• Display summary statistics.
df.describe()
print(df)
#• Convert Age and CreditScore to float.
df["CreditScore"] = df["CreditScore"].astype(float)
print(df["CreditScore"])
#• Display information again.
df.info
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 3 – Duplicate Investigation
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Find duplicate customers.
duplicates = df[df.duplicated()]
print(duplicates)
#Then
#• Count duplicate rows.
df1 = df.duplicated().sum()
print(df1)
#• Remove duplicates.
df.dropna(inplace = True)
df
#• Print information before and after removing duplicates.
df.info()

#• Show the last 20 rows.
df.tail()
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1000       10643  41.0      125012.0     18825          761   35977.85
# 1001       10763  56.0      102965.0     17517          838  115028.54
# 1002       10910  66.0      118506.0      6296          306   81892.13
# 1003       10200  19.0      115052.0     20741          484  190233.86
# 1004       10587  29.0           NaN     40255          383  168358.60
# 1005       10798  22.0      176830.0      7626          688   65481.65
# 1006       10653  32.0           NaN     21266          598  142086.70
# 1007       10756  53.0       74430.0      3705          489   29651.23
# 1008       10417  70.0       40417.0     37956          681   23880.19
# 1009       10499  34.0      166546.0     12497          643  130886.93
# 1010       10515  62.0      199762.0     41808          309   60223.29
# 1011       10457  44.0       63604.0     27633          804  176354.13
# ...

# %%
#Challenge 4 – HR Department
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#HR wants better column names.
df.columns
print(df)
#Rename
#CustomerID → Employee_ID
#Age → EmployeeAge
#Gender → EmployeeGender
#AnnualIncome → Salary
#Target → PromotionStatus
df.rename(columns = {
    "CustomerID":"Employee_ID",
    "Age":"EmployeeAge",
    "Gender":"EmployeeGender",
    "AnnualIncome":"Salary",
    "Target":"PromotionStatus"
},inplace = True)
print(df)
#Then
#• Add prefix
#HR_ to every column.
df.add_prefix("HR_")
print(df)
#Display 10 random records.
df.tail(10)
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 5 – Finance Cleaning
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")

#Finance department reports missing values.
df.isnull().sum()
print(df)

##---->Tasks
#Fill
#AnnualIncome → Median
AnnualIncome_median = df["AnnualIncome"].median()
AnnualIncome_median
df["AnnualIncome"] = df["AnnualIncome"].fillna(AnnualIncome_median)
print(df["AnnualIncome"])

#Balance → Mean
Balance_Mean = df["Balance"].fillna(df["Balance"].mean())
print(Balance_Mean)

#Age → Median
Age_median = df["Age"].median()
Age_median
df["Age_median"] = df["Age"].fillna(AnnualIncome_median)
print(df["Age_median"])

#Then
#Generate descriptive statistics.
df.describe()
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 6 – Data Type Audit
#The company says
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Age and AnnualIncome are stored incorrectly.
df.dropna(inplace = True)

#--->Tasks
#Convert
#Age → int

df["Age"] = df["Age"].astype(int)
df["Age"] 
#AnnualIncome → float
df["AnnualIncome"] = df["AnnualIncome"].astype(float)
df["AnnualIncome"] 
#Balance → float
df["Balance"] = df["Balance"].astype(float)
df["Balance"] 
#Target → string
df["Target"] = df["Target"].astype(str)
df["Target"] 
#Print information.
df.info
# Out:
# <bound method DataFrame.info of       CustomerID  Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 1          10002   65      162964.0      6197          732    6356.54       1
# 2          10003   56       26956.0     37281          503  143203.92       8
# 4          10005   66      108236.0      7198          394   75985.46       5
# 5          10006   69       31390.0     48323          770  107245.62       6
# 6          10007   58      182141.0     24200          891   38457.72       1
# ...          ...  ...           ...       ...          ...        ...     ...
# 1011       10457   44       63604.0     27633          804  176354.13       5
# 1013       10531   64       85162.0     32083          654  132742.13      10
# 1014       10181   50      166466.0     44281          662   14415.10       0
# 1015       10450   43      173620.0      7121          644   60353.03       2
# 1017       10810   49       82062.0     47170          813   53850.09       8
#
# ...

# %%
#Challenge 7 – Customer Analytics
#Create a new DataFrame that
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")

#• removes Segment
df.drop('Segment', axis = 1 , inplace = True)

#• removes Geography
df.drop('Geography', axis = 1 , inplace = True)

#• removes duplicate rows
df.dropna(inplace = True)
df
#Display

#• first 10 rows
df.head()
print(df)
#• dataset information
df.info()
print(df)
#• statistical summary
df.describe()
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# 5          10006  69.0       31390.0     48323          770  107245.62
# ...          ...   ...           ...       ...          ...        ...
# 1012       10882  61.0      115417.0      3879          413   76591.00
# 1013       10531  64.0       85162.0     32083          654  132742.13
# 1014       10181  50.0      166466.0     44281          662   14415.10
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1017       10810  49.0       82062.0     47170          813   53850.09
#
#       Tenure  Gender Target
# 1          1    Male  Churn
# 2          8    Male   Stay
# ...

# %%
#Challenge 8 – ML Dataset Preparation
#Prepare a machine learning dataset.
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#---->Perform
#• Remove duplicates
df.dropna(inplace = True)
print(df)
#• Remove CustomerID
df.drop('CustomerID',axis = 1,inplace = True)
print(df)
#• Remove Segment
df.drop('Segment', axis = 1 ,inplace = True)
print(df)
#• Fill missing values
df.isna()
print(df)
#• Rename Target to Output
df.rename(columns = {"Target":"Output"},inplace = True)
print(df)
#Finally Display
#head()
df.head()
print(df)
#info()
df.info()
print(df)
#describe()
df.describe()
print(df)
#value_counts(Output)
df.value_counts
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 4          10005  66.0      108236.0      7198          394   75985.46
# 5          10006  69.0       31390.0     48323          770  107245.62
# 6          10007  58.0      182141.0     24200          891   38457.72
# ...          ...   ...           ...       ...          ...        ...
# 1011       10457  44.0       63604.0     27633          804  176354.13
# 1013       10531  64.0       85162.0     32083          654  132742.13
# 1014       10181  50.0      166466.0     44281          662   14415.10
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1017       10810  49.0       82062.0     47170          813   53850.09
#
#       Tenure Geography  Gender    Segment Target
# 1          1       USA    Male        SME  Churn
# ...

# %%
#Challenge 9 – Column Transformation
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Create these new columns
#NetWorth = Balance + AnnualIncome
df['NetWorth'] = df['Balance'] + df['AnnualIncome']


#AgeAfterRetirement = Age + 20
df['AgeAfterRetirement'] = df['Age'] + 20


#DoubleCreditScore = CreditScore * 2
df['DoubleCreditScore'] = df['CreditScore'] * 2


#IncomePerMonth = AnnualIncome / 12
df['IncomePerMonth'] = df['AnnualIncome'] /12


#Then
#Display first 15 rows.
df.head(15)
# Out:
#     CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0        10001  58.0       49184.0      2139          581        NaN       2
# 1        10002  65.0      162964.0      6197          732    6356.54       1
# 2        10003  56.0       26956.0     37281          503  143203.92       8
# 3        10004  55.0       92926.0       925          463  139627.88       5
# 4        10005  66.0      108236.0      7198          394   75985.46       5
# 5        10006  69.0       31390.0     48323          770  107245.62       6
# 6        10007  58.0      182141.0     24200          891   38457.72       1
# 7        10008  67.0       95861.0      5729          538  173296.73       6
# 8        10009  41.0       62638.0     24760          663   41901.41       4
# 9        10010  22.0      179680.0     42113          475  106827.98       3
# 10       10011   NaN      187772.0     45599          870   43923.03       5
# ...

# %%
#Challenge 10 – Company Report
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Display
#• first five rows
df.head(5)


#• last five rows
df.tail(5)


#• ten random rows
df.sample(10)


#• dataset information
df.info()


#• descriptive statistics
df.describe()
#Finally rename
#Target → Customer_Status
df.rename(columns = {'Target':'Customer_Status'
},inplace = True)
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# ...

# %%
#Challenge 11 – Missing Value Report
#Create a report showing
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#• Total missing values
df.isnull().sum()
#• Numerical columns
df.select_dtypes(include = ["int"]).columns
#• Mean of Balance
df['Balance'] = df['Balance'].mean()
df['Balance']
#• Median of Age
AgeAge = df["Age"].median()
AgeAge
#• Fill missing values
df.dropna()
#• Display information again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
#Challenge 12 – Customer Classification
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
df
#Count
#Stay
#Churn
df.value_counts('Target')
print(df)
#Then
#Rename
#Target → Customer_Class
df.rename(columns = {"Target":"Customer_Class"},inplace = True)
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 13 – Sales Department
#Rename
#Balance → AccountBalance
#AnnualIncome → Salary
#CreditScore → CreditScore
df.rename(columns = {
    "Balance":"AccountBalance",
    "AnnualIncome":"Salary",
    "CreditScore":"CreditScore"
})
#Add prefix
#Sales_
df.add_prefix("Sales_")
#Then
#Display
#sample(20)
df.sample(20)
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 907       10908  36.0       62936.0     48210          734  145721.10       6
# 690       10691  42.0      192470.0     32606          838  124794.10       9
# 541       10542  47.0       69959.0     47475          646   21553.15       6
# 432       10433  18.0       36166.0     15067          433   39626.61       6
# 43        10044  31.0      109884.0     13842          570  101081.81       4
# 878       10879  43.0       68482.0     24775          775  140780.41       0
# 15        10016  68.0      198384.0     28166          365   76953.46       9
# 419       10420  57.0       83591.0     30903          677  118338.19       7
# 414       10415  33.0       32053.0     31417          672   76595.89       2
# 689       10690  29.0       28198.0     13743          409   97074.06       1
# 623       10624  41.0       82719.0     43427          300  195129.18       1
# ...

# %%
#Challenge 14 – Interview Challenge
#Without creating another DataFrame,
#perform
#• remove duplicates
df.duplicated().sum()
print(df)
#• rename Target
df.rename(columns = {'Customer_Class':'Target'},inplace = True)
print(df)
#• fill missing values
#• convert Balance to float
#• display summary
df.describe()
print(df)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 15 – Data Engineer Task
#Load the dataset.
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Create another DataFrame containing only numeric columns.
s = df.select_dtypes(include = ["float"]).columns
len(s)
#Drop
#CustomerID
#Target
df.drop('CustomerID', axis = 1 ,inplace = True)
df.drop('Target', axis = 1 ,inplace = True)
print(df)
#Display summary.
df.describe()
# Out:
#        Age  AnnualIncome  Spending  CreditScore    Balance  Tenure Geography  \
# 0     58.0       49184.0      2139          581        NaN       2    France
# 1     65.0      162964.0      6197          732    6356.54       1       USA
# 2     56.0       26956.0     37281          503  143203.92       8    Canada
# 3     55.0       92926.0       925          463  139627.88       5       NaN
# 4     66.0      108236.0      7198          394   75985.46       5        UK
# ...    ...           ...       ...          ...        ...     ...       ...
# 1015  43.0      173620.0      7121          644   60353.03       2       USA
# 1016  25.0       54490.0     13794          303  124512.07       4     India
# 1017  49.0       82062.0     47170          813   53850.09       8   Germany
# 1018  38.0           NaN     10424          722  138100.05       6   Germany
# 1019  62.0       97504.0     36833          430        NaN      10    Canada
#
#       Gender    Segment
# ...

# %%
#Challenge 16 – Mixed Cleaning
#Perform
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")

#drop_duplicates()
df.drop_duplicates()
print(df)

#fillna()
df["Age"].fillna(method = "ffill",inplace = True)
print(df)

#astype()
df["Age"] = df["Age"].astype(float)
print(df)
#rename()
df.rename(columns={"Age": "new_age"}, inplace=True)
print(df)
#head()
df.head()
print(df)

#info()
df.info()

#using only one DataFrame variable.
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 17 – Real Company Dataset
#Manager asks
#Remove duplicate records
df.dropna()
df
#Fill missing values
df.isnull()
#Rename all business columns

#Add company prefix
df.add_prefix('company__')
#Display summary
df.describe()
#Display target counts
df.info('Tenure')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   new_age       1020 non-null   float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
#Challenge 18 – Customer Summary
#Generate
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
#Mean Balance
df['Balance'] = df['Balance'].mean()
df['Balance']
#Median Balance
df['Balance_median'] = df["Balance"].median()
AnnualIncome_median
df["Balance_median"] = df["Balance"].fillna(AnnualIncome_median)
print(df["Balance_median"])

#Mean Age
df['Age_Mean'] = df['Age'].mean()
df['Age_Mean']
df["Age_Mean"] = df["Age"].fillna(AnnualIncome_median)
print(df["Age_Mean"])

#Median AnnualIncome
df['AnnualIncome_median'] = df["AnnualIncome"].median()
AnnualIncome_median
df["AnnualIncome_median"] = df["AnnualIncome"].fillna(AnnualIncome_median)
print(df["AnnualIncome_median"])
#Then
#fill missing values using these statistics.
# Out:
# 0       97523.535666
# 1       97523.535666
# 2       97523.535666
# 3       97523.535666
# 4       97523.535666
#             ...
# 1015    97523.535666
# 1016    97523.535666
# 1017    97523.535666
# 1018    97523.535666
# 1019    97523.535666
# Name: Balance_median, Length: 1020, dtype: float64
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: Age_Mean, Length: 1020, dtype: float64
# 0        49184.0
# 1       162964.0
# 2        26956.0
# 3        92926.0
# 4       108236.0
#           ...
# 1015    173620.0
# 1016     54490.0
# 1017     82062.0
# 1018    112358.0
# 1019     97504.0
# Name: AnnualIncome_median, Length: 1020, dtype: float64

# %%
#Challenge 19 – Transformation Challenge
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
print(df)
#Create
#Income_in_Lakhs
df['AnnualIncome'] = df['AnnualIncome'] /100000
print(df)
#Balance_in_Lakhs
df['Balance'] = df['Balance'] /100000
print(df)
#SeniorCitizen
df["SeniorCitizen"] = ["older"if age > 45 else "Young "for age in df["Age"]]
print(df["SeniorCitizen"])
#HighCreditScore
df["CreditScore_avg"] = ["HighCreditScore"if age > 500 else "LowCreditScore "for age in df["CreditScore"]]
print(df["CreditScore_avg"])
print(df)
#where
#SeniorCitizen = Age + 0
df["SeniorCitizen"]  = df["Age"]  + 0
print(df["SeniorCitizen"])
#HighCreditScore = CreditScore * 1
df["CreditScore_avg"] = df["CreditScore"] * 1
print(df["CreditScore_avg"])
#(No conditional statements.)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
#Challenge 20 – Final Interview Project
#Your manager gives you a dirty customer dataset.
#Prepare the final dataset.
#Requirements
#Load datase
df = pd.read_csv("C:/Users/anilr/Downloads/Task_dataset (1).csv")
df
#Check information
df.info()
print(df)
#Find missing values
df.isnull()
print(df)
#Remove duplicates
df.dropna()
print(df)
#Rename
#CustomerID
#AnnualIncome
#CreditScore
#Target
df.rename(columns = {
    "CustomerID":"Customer_ID",
    "AnnualIncome":"Annual_Income",
    "CreditScore":"Credit_Score",
    "Target":"Output"
},inplace = True)
print(df)

#Convert
#Age
#AnnualIncome
#Balance
#Fill missing values
#Remove
#Segment
#CustomerID
#Create new columns
#TotalMoney = Balance + AnnualIncome
#df['TotalMoney'] = df['Balance'] + df['Annual_Income']

#AgeAfter5Years = Age + 5
#df['AgeAfter5Years'] = df['Age'] + 5
#df['AgeAfter5Years']


#MonthlyIncome = AnnualIncome / 12
#df['MonthlyIncome'] = df['Annual_Income'] / 12
#CreditScoreDouble = CreditScore * 2Display
#df['CreditScoreDouble'] = df['Credit_Score'] * 2
#df['CreditScoreDouble']
#• Head
df.head()
print(df)
#• Tail
df.tail()
print(df)
#• Sample
df.sample()
print(df)
#• Describe
df.describe()
print(df)
#• Target counts

#• Final information
df.info
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# ...

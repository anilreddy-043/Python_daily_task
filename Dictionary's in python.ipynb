# %%
#1  Create a dictionary student with keys: "name", "age", "city" and print it. 

Anil = {"name":"Anil","Age":10,"City":"Khammam"}
Anil
# Out:
# {'name': 'Anil', 'Age': 10, 'City': 'Khammam'}

# %%
# 2  Given d = {"a": 1, "b": 2, "c": 3}, print all keys using keys() method. 

d = {"a": 1, "b": 2, "c": 3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# 3 Given d = {"a": 1, "b": 2}, print all values using values() method. 

d = {"a": 1, "b": 2}
d.values()
# Out:
# dict_values([1, 2])

# %%
# 4   Use get() method to safely get the value of key "name" from dictionary d = {"name": "Sumit", "age": 25}.


d = {"name": "Sumit", "age": 25}
d.get("name")
# Out:
# 'Sumit'

# %%
# 5 Create a tuple with 5 numbers and print its type and length. 

Anil = (1,2,3,4,5,6)
Anil
type(Anil)
Anil
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# 6 Create a tuple tup = (10, 20, 30, 40, 50) and use count() to count how many times 20 appears. 
tup = (10, 20, 30, 40, 50)
tup.count(20)
# Out:
# 1

# %%
# 7. Use index() method on tuple (10, 20, 30, 40) to find the position of 30.

tuple1 = (10, 20, 30, 40)
tuple1.index(30)
# Out:
# 2

# %%
# 8. Create an empty dictionary and add 3 key-value pairs using assignment. 

d = {}
d["name"] = "Anil"
d["age"] = 20
d["city"] = "Hyderabad"
d
# Out:
# {'name': 'Anil', 'age': 20, 'city': 'Hyderabad'}

# %%
# 9  Given d = {"a": 1, "b": 2}, use update() to add {"c": 3, "d": 4}. 
d = {"a": 1, "b": 2}
e =  {"c": 3, "d": 4}
d.update(e)
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 10. Remove the key "age" from dictionary student = {"name": "Rahul", "age": 22, "city": "Delhi"} using pop().

student = {"name": "Rahul", "age": 22, "city": "Delhi"}
student.pop("age")
student
# Out:
# {'name': 'Rahul', 'city': 'Delhi'}

# %%
#11. Use popitem() on dictionary d = {"x": 10, "y": 20, "z": 30} and print the removed item.

d = {"x": 10, "y": 20, "z": 30}
d.popitem()
#d
# Out:
# ('z', 30)

# %%
#12. Create a copy of dictionary original = {"a": 1, "b": 2} using copy() method.

p = {"a": 1, "b": 2}
p.copy()
# Out:
# {'a': 1, 'b': 2}

# %%
# 13. Use fromkeys() to create a dictionary with keys ["red", "green", "blue"] and default value 0.
colors = ["red", "green", "blue"]
dict.fromkeys(colors, 0)
# Out:
# {'red': 0, 'green': 0, 'blue': 0}

# %%
#  14. Create a tuple with mixed data types and try to change one element (show error). 
a = (8,5.24)

a.pop(8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 #  14. Create a tuple with mixed data types and try to change one element (show error).
#       2 a = (8,5.24)
# ----> 4 a.pop(8)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
#  15.  Given d = {"name": "Sumit"}, use setdefault("age", 25) and print the dictionary. 

d = {"name": "Sumit"} 
d.setdefault("age", 25)
d
# Out:
# {'name': 'Sumit', 'age': 25}

# %%
# 16 Create a dictionary. Add 3 items using update(), then remove the last inserted item using popitem().

d =  {}
type(d)
d =  {"name": "Rahul", "age": 22, "city": "Delhi"}
d.update(d)
d
d.pop("city")
d
# Out:
# {'name': 'Rahul', 'age': 22}

# %%
#  17  Create a tuple of 6 numbers. Find the index of a number and count how many times it appears. 

t = (1,2,3,5,3,3)
t.index(3)
t.count(3)
# Out:
# 3

# %%
# 18. Take 3 student names and marks as input and store them in a dictionary (name as key, mark as value)
 #{"ram":91,"anil":56,"babu":99}
p = {"ram":91,"anil":56,"babu":99}
p
# Out:
# {'ram': 91, 'anil': 56, 'babu': 99}

# %%
#  19. Given data = {"a": 10, "b": 20, "c": 10}, use items() and print only keys where value is 10. 

data = {"a": 10, "b": 20, "c": 10}
data.items()
data
data.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
#  20. Create a dictionary of 5 items, make a copy, clear the original dictionary, and show both.

daa = {"name": "Rahul", "age": 22, "city": "Delhi"}
daa1 = daa.copy()
daa1
daa.clear()
daa
print(daa1)
print(daa)
# Out:
# {'name': 'Rahul', 'age': 22, 'city': 'Delhi'}
# {}

# %%
#21

daa = {"name": "Rahul", "age": 22, "city": "Delhi"}
daa1 = {"mob-no":63963}
daa.update(daa1)
daa
daa.popitem()
daa.items()
# Out:
# dict_items([('name', 'Rahul'), ('age', 22), ('city', 'Delhi')])

# %%
#22

daa = (1,2,56,789,25,741,852,456,7523,25)
type(daa)
daa.index(25)
daa.count(25)
daa = list(daa)
daa
type(daa)
daa.sort()
daa
# Out:
# [1, 2, 25, 25, 56, 456, 741, 789, 852, 7523]

# %%
# 24
info = {"name": "Aman", "age": 21, "city": "Mumbai"}
info1 = info.copy()
info1
info.clear()

# %%
# 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

set1 =  {1, 2, 3, 2, 4, 1}
set1
# Out:
# {1, 2, 3, 4}

# %%
#  2. (Easy) Create an empty set using correct syntax and add 3 numbers using add(). 
set1 = set()
type(set1)
set1.add(3)
set1
# Out:
# {3}

# %%
#3 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().
s = {10, 20, 30}
s1 = [40, 50, 60]
s.update(s1)
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# 4  (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

s = {10, 20, 30, 40}
s.remove(20)
s
s.discard(10)
s
# Out:
# {30, 40}

# %%
# 5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

A = {1, 2, 3, 4} 
B = {3, 4, 5, 6}
A = A.union(B)
A
B = A.intersection(B)
B
c = A.difference(B)
c
# Out:
# {1, 2}

# %%
# 6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword. 
s = {10, 20, 30, 40}
s = "yes" * (20) or "no"
s
# Out:
# 'yesyesyesyesyesyesyesyesyesyesyesyesyesyesyesyesyesyesyesyes'

# %%
#7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its length. 

list1 = [1, 2, 2, 3, 4, 4, 5]
len(list1)
# Out:
# 7

# %%
#8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only. 

s = set(input())
type(s)
print(s)
# Out:
#  10'20,30
# {'0', '1', '2', "'", '3', ','}

# %%
# 9.  (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B. 

A = {1, 2, 3}
B = {3, 4, 5}
A.difference(B)
# Out:
# {1, 2}

# %%
#10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?
s = set({1,2,3,4,5,6})
list1 = [1,2,3]
s
#This error occurs because sets in Python can only contain **hashable** 
#(immutable) objects, and lists are **unhashable** (mutable). 
#Since lists can be modified after creation, they cannot be used as elements in a set.
# Out:
# {1, 2, 3, 4, 5, 6}
